# %% [markdown]
# # ライブラリ実装

# %%
# Author: Jake Vanderplas <jakevdp@cs.washington.edu>
#
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from distutils.version import LooseVersion
from scipy.stats import norm
from sklearn.neighbors import KernelDensity

# `normed` is being deprecated in favor of `density` in histograms
if LooseVersion(matplotlib.__version__) >= '2.1':
    density_param = {'density': True}
else:
    density_param = {'normed': True}

#----------------------------------------------------------------------
# Plot a 1D density example
N = 100
np.random.seed(1)
X = np.concatenate((np.random.normal(0, 1, int(0.3 * N)),
                    np.random.normal(5, 1, int(0.7 * N))))[:, np.newaxis]

X_plot = np.linspace(-5, 10, 1000)[:, np.newaxis]

true_dens = (0.3 * norm(0, 1).pdf(X_plot[:, 0])
             + 0.7 * norm(5, 1).pdf(X_plot[:, 0]))

fig, ax = plt.subplots()
ax.fill(X_plot[:, 0], true_dens, fc='black', alpha=0.2,
        label='input distribution')

for kernel in ['gaussian']:
    kde = KernelDensity(kernel=kernel, bandwidth=0.5).fit(X)
    log_dens = kde.score_samples(X_plot)
    ax.plot(X_plot[:, 0], np.exp(log_dens), '-',
            label="kernel = '{0}'".format(kernel))

ax.text(6, 0.38, "N={0} points".format(N))

ax.legend(loc='upper left')
ax.plot(X[:, 0], -0.005 - 0.01 * np.random.random(X.shape[0]), '+k')

ax.set_xlim(-4, 9)
ax.set_ylim(-0.02, 0.4)
plt.show()

# %%
X_plot
# Out:
# array([[ -5.        ],
#        [ -4.98498498],
#        [ -4.96996997],
#        [ -4.95495495],
#        [ -4.93993994],
#        [ -4.92492492],
#        [ -4.90990991],
#        [ -4.89489489],
#        [ -4.87987988],
#        [ -4.86486486],
#        [ -4.84984985],
#        [ -4.83483483],
#        [ -4.81981982],
#        [ -4.8048048 ],
#        [ -4.78978979],
#        [ -4.77477477],
#        [ -4.75975976],
#        [ -4.74474474],
#        [ -4.72972973],
#        [ -4.71471471],
#        [ -4.6996997 ],
#        [ -4.68468468],
#        [ -4.66966967],
#        [ -4.65465465],
#        [ -4.63963964],
#        [ -4.62462462],
#        [ -4.60960961],
#        [ -4.59459459],
#        [ -4.57957958],
#        [ -4.56456456],
#        [ -4.54954955],
#        [ -4.53453453],
#        [ -4.51951952],
#        [ -4.5045045 ],
#        [ -4.48948949],
#        [ -4.47447447],
#        [ -4.45945946],
#        [ -4.44444444],
#        [ -4.42942943],
#        [ -4.41441441],
# ...

# %%
import math

# ガウスカーネルの定義

def kernel(xi, xj, beta):
    return np.exp(- beta * np.sum((xi - xj)**2))
band = 30


 
norm = 1/(2 * math.pi * band)**0.5

def sample(x):
    return np.sum(list(map(lambda xn: norm * kernel(x, xn, band), data)))/data.shape[0]

# %%
X
# Out:
# array([[ 1.62434536],
#        [-0.61175641],
#        [-0.52817175],
#        [-1.07296862],
#        [ 0.86540763],
#        [-2.3015387 ],
#        [ 1.74481176],
#        [-0.7612069 ],
#        [ 0.3190391 ],
#        [-0.24937038],
#        [ 1.46210794],
#        [-2.06014071],
#        [-0.3224172 ],
#        [-0.38405435],
#        [ 1.13376944],
#        [-1.09989127],
#        [-0.17242821],
#        [-0.87785842],
#        [ 0.04221375],
#        [ 0.58281521],
#        [-1.10061918],
#        [ 1.14472371],
#        [ 0.90159072],
#        [ 0.50249434],
#        [ 0.90085595],
#        [-0.68372786],
#        [-0.12289023],
#        [-0.93576943],
#        [-0.26788808],
#        [ 0.53035547],
#        [ 4.30833925],
#        [ 4.60324647],
#        [ 4.3128273 ],
#        [ 4.15479436],
#        [ 4.32875387],
#        [ 4.9873354 ],
#        [ 3.88268965],
#        [ 5.2344157 ],
#        [ 6.65980218],
#        [ 5.74204416],
#        [ 4.80816445],
# ...

# %% [markdown]
# # データの準備

# %%
import matplotlib.pyplot as plt
from numpy.random import rand
from numpy.random import randn
import numpy as np
from numpy import append
from sklearn.cross_validation import KFold
 
data = []
u = randn(1000)
v = rand(500)
data = append(data, v)
data = append(data, u*2+ 1)
data = append(data, u + 5)
 
plt.hist(data, bins = 50)
plt.show()

# %% [markdown]
# # numpy のみでの実装

# %%
import math

# ガウスカーネルの定義

def kernel(xi, xj, beta):
    return np.exp(- beta * np.sum((xi - xj)**2))
band = 30


 
norm = 1/(2 * math.pi * band)**0.5

def sample(x):
    return np.sum(list(map(lambda xn: norm * kernel(x, xn, band), data)))/data.shape[0]

# %%
kernel(x, 2, band)

# %%
import numpy as np

x = np.linspace(-6,8, 100)

# %%
y = [sample(i) for i in x]

# %%
fig = plt.figure() 
ax = plt.axes() 


ax.plot(x,y)
 
weights = np.ones(len(data))
weights = np.ones(len(data))/float(len(data))
ax.hist(data, weights=weights, bins = 50)
plt.show()
